# %% [markdown]
# Install Packages

# %%
# Upgrade pip using the Python interpreter as a module
# !python -m pip install --upgrade pip
# Install TensorBoard version 2.4.1 using pip
# !pip install tensorboard==2.4.1
# Install Torch using pip
# !pip install torch

# %%
# Importing the torch library
import torch

# %%
# Importing the Image class from the IPython.display module
from IPython.display import Image

# %%
# Cloning the yolov5 repository from the Github URL using the git command
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15921, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 15921 (delta 16), reused 24 (delta 9), pack-reused 15880
# Receiving objects: 100% (15921/15921), 14.60 MiB | 19.14 MiB/s, done.
# Resolving deltas: 100% (10915/10915), done.

# %%
# Changing the current directory to the 'yolov5' directory
# %cd yolov5
# Out:
# /content/yolov5

# %%
# Installing the Python packages specified in the requirements.txt file using the pip command
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.0/613.0 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.1 MB/s eta 0:00:00
# ...

# %%
# Importing the 'drive' module from the 'google.colab' package
from google.colab import drive

# Mounting the Google Drive to the '/content/drive' directory
drive.mount('/content/drive')

# %%
# Unzipping the 'price tag dataset 2.zip' file
# !unzip -q '/content/drive/MyDrive/rips ucla/SAP_RIPS_ComputerVision/datasets/price tag dataset 2.zip' -d '/content/'

# %%
# Installing the 'clearml' Python package
# !pip install clearml

import clearml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 8.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyjwt
#     Found existing installation: PyJWT 2.3.0
#     Uninstalling PyJWT-2.3.0:
#       Successfully uninstalled PyJWT-2.3.0
# ...

# %%
# Setting the environment variables for ClearML web, API, files, access key, and secret key

# %env CLEARML_WEB_HOST=https://app.clear.ml
# %env CLEARML_API_HOST=https://api.clear.ml
# %env CLEARML_FILES_HOST=https://files.clear.ml
# %env CLEARML_API_ACCESS_KEY=AA6ZIRLIK0457VZ54EYD
# %env CLEARML_API_SECRET_KEY=H2Am7Heo1uEAgqgfU8UCfdLQ1OlPQi6iH8ct1TQIo6PUot7qGk
# Out:
# env: CLEARML_WEB_HOST=https://app.clear.ml
# env: CLEARML_API_HOST=https://api.clear.ml
# env: CLEARML_FILES_HOST=https://files.clear.ml
# env: CLEARML_API_ACCESS_KEY=AA6ZIRLIK0457VZ54EYD
# env: CLEARML_API_SECRET_KEY=H2Am7Heo1uEAgqgfU8UCfdLQ1OlPQi6iH8ct1TQIo6PUot7qGk

# %%
# Importing the 'Task' class from the 'clearml' module
from clearml import Task
# Creating and initializing a new task
task = Task.init(project_name="YOLOv5_tag_detection", task_name="detection_training")
# Out:
# ClearML Task: created new task id=8f3c23db9b9f412da97e7689d528a1e9
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.util has been moved to tensorflow.python.checkpoint.checkpoint. The old module will be deleted in version 2.11.
# ClearML results page: https://app.clear.ml/projects/7ca5430212c346fea1632e09107f4f83/experiments/8f3c23db9b9f412da97e7689d528a1e9/output/log

# %% [markdown]
# ## Train

# %%
# Running the training script
# !python train.py --img 640 --batch 80 --epochs 300 --data '/content/train-tag-yolov8.yml' --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/train-tag-yolov8.yml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=80, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-203-g0897415 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# Loading the TensorBoard extension
# %load_ext tensorboard
# %tensorboard --logdir runs

# %% [markdown]
# **Validation**

# %%
# Running the validation script on test
# !python val.py --data '/content/train-tag-yolov8.yml' --task test --weights '/content/yolov5/runs/train/exp2/weights/best.pt'
# Out:
# val: data=/content/train-tag-yolov8.yml, weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-203-g0897415 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# test: Scanning /content/price tag dataset 2/price tag/test/labels... 260 images, 0 backgrounds, 0 corrupt: 100% 260/260 [00:00<00:00, 5332.32it/s]
# test: New cache created: /content/price tag dataset 2/price tag/test/labels.cache
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  22% 2/9 [00:08<00:27,  3.94s/it]WARNING ⚠️ NMS time limit 2.100s exceeded
# ...

# %%
# Running the validation script on validation images
# !python val.py --data '/content/train-tag-yolov8.yml' --task val --weights '/content/yolov5/runs/train/exp2/weights/best.pt'
# Out:
# val: data=/content/train-tag-yolov8.yml, weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-203-g0897415 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning /content/price tag dataset 2/price tag/val/labels.cache... 289 images, 0 backgrounds, 0 corrupt: 100% 289/289 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 10/10 [00:09<00:00,  1.10it/s]
#                    all        289        959      0.896      0.876      0.916      0.648
# ...

# %% [markdown]
# # Adding collected images

# %%
from clearml import Task
# Creating and initializing a new task
task = Task.init(project_name="YOLOv5_tag_detection_adding_collected", task_name="detection_training")
# Out:
# ClearML Task: created new task id=bc2acd10b8c64a7dba848badd18407d7
# 2023-08-11 04:29:44,727 - clearml.Task - INFO - Storing jupyter notebook directly as code
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.util has been moved to tensorflow.python.checkpoint.checkpoint. The old module will be deleted in version 2.11.
# ClearML results page: https://app.clear.ml/projects/7e20e1a48a6045059a6df7b7ea4a2333/experiments/bc2acd10b8c64a7dba848badd18407d7/output/log

# %%
# Unzipping price tag v3.zip
# !unzip -q '/content/drive/MyDrive/rips ucla/SAP_RIPS_ComputerVision/datasets/price tag v3.zip' -d '/content/'

# %%
#train on collected images
# !python train.py --img 640 --batch 80 --epochs 300 --data '/content/drive/MyDrive/rips ucla/SAP_RIPS_ComputerVision/price_tag_detection_model/train_price_tag_collected+extended.yml' --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/drive/MyDrive/rips ucla/SAP_RIPS_ComputerVision/price_tag_detection_model/train_price_tag_collected+extended.yml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=80, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-209-g493981c Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
#run validation script on validation images
# !python val.py --data '/content/drive/MyDrive/rips ucla/SAP_RIPS_ComputerVision/price_tag_detection_model/train_price_tag_collected+extended.yml' --task val --weights '/content/yolov5/runs/train/exp/weights/best.pt'
# Out:
# val: data=/content/drive/MyDrive/rips ucla/SAP_RIPS_ComputerVision/price_tag_detection_model/train_price_tag_collected+extended.yml, weights=['/content/yolov5/runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-209-g493981c Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning /content/price tag/val/labels.cache... 310 images, 0 backgrounds, 0 corrupt: 100% 310/310 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95:  20% 2/10 [00:08<00:29,  3.74s/it]WARNING ⚠️ NMS time limit 2.100s exceeded
# ...

# %%
#run validation script on test data
# !python val.py --data '/content/drive/MyDrive/rips ucla/SAP_RIPS_ComputerVision/price_tag_detection_model/train_price_tag_collected+extended.yml' --task test --weights '/content/yolov5/runs/train/exp/weights/best.pt'
# Out:
# val: data=/content/drive/MyDrive/rips ucla/SAP_RIPS_ComputerVision/price_tag_detection_model/train_price_tag_collected+extended.yml, weights=['/content/yolov5/runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-209-g493981c Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# test: Scanning /content/price tag/test/labels... 281 images, 0 backgrounds, 0 corrupt: 100% 281/281 [00:00<00:00, 2717.55it/s]
# test: New cache created: /content/price tag/test/labels.cache
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 9/9 [00:23<00:00,  2.60s/it]
# ...
